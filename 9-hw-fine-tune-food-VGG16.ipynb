# %% [markdown]
# # Transfer learning: classifying food items
#
# _Fraida Fund_

# %% [markdown]
# * Name: Ziyi Liang
# * Net ID: zl5604

# %% [markdown]
# This week, we practiced using transfer learning to classify hand shapes as rock, paper, or scissors.
#
# But that was a relatively easy problem. In this notebook, we'll work on classifying photographs of food items into 11 classes: bread, dairy product, dessert, egg, fried food, meat, noodles/pasta, rice, seafood, soup, and vegetable/fruit.
#
# This is a more challenging problem, because there is a lot of intra-class variability (e.g. different fruits and vegetables don't have a lot in common) and also some inter-class similarity (e.g. a bowl of rice can look similar to a bown of pasta).
#
# To see what we mean by these, let's look at some examples of food photographs from the dataset that we'll work with.

# %% [markdown]
# Note: you can refer to this week's demo notebook for a closely related example.
#
# Note: you may want to change the notebook's runtime type to GPU, for faster model training.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import shutil
from PIL import Image

import tensorflow.keras.backend as K
import tensorflow as tf

from tensorflow import clip_by_value
from tensorflow import data as tf_data
from tensorflow import image as tf_image
from tensorflow import random as tf_random

# %% [markdown]
# ## Get data
#
# We are going to use the [Food-11 dataset](https://www.epfl.ch/labs/mmspg/downloads/food-image-datasets/), from the EPFL Multimedia Signal Processing Group. Here's a description:
#
# > This is a dataset containing 16643 food images grouped in 11 major food categories. The 11 categories are Bread, Dairy product, Dessert, Egg, Fried food, Meat, Noodles/Pasta, Rice, Seafood, Soup, and Vegetable/Fruit. Similar as Food-5K dataset, the whole dataset is divided in three parts: training, validation and evaluation. The same naming convention is used, where ID 0-10 refers to the 11 food categories respectively.
# >
# > The total file size of the Food-11 dataset is about 1.16 GB.

# %%
classes = np.array(["Bread", "Dairy product", "Dessert", "Egg", "Fried food",
	"Meat", "Noodles/Pasta", "Rice", "Seafood", "Soup",
	"Vegetable/Fruit"])

# %%
# !mkdir -p /content/Food-11
# %cd /content/Food-11
# !gdown https://drive.google.com/uc?id=1dt3CD3ICdLbTf80sNJ25TPBDKu_qyCnq
# Out:
# [WinError 3] 系统找不到指定的路径。: '/content/Food-11'
# d:\文档\NYU Classes\2023 Fall\ECE-GY 6143 Machine Learning\Lab 11
# �����﷨����ȷ��
# 'gdown' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���

# %%
# !unzip Food-11.zip
# Out:
# 'unzip' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���

# %%
# %cd ./content
# Out:
# d:\文档\NYU Classes\2023 Fall\ECE-GY 6143 Machine Learning\Lab 11\content

# %% [markdown]
# Click on the folder icon in Colab to view your filesystem and verify that you have the `Food-11` directory with `training`, `validation`, and `evaluation` subdirectories.

# %%
# Some codes are modified to be able to run on Windows and make use of hardware acceleration

root_dir = r"D:\文档\NYU Classes\2023 Fall\ECE-GY 6143 Machine Learning\Lab 11"
training_dir = "Food-11/training/"
validation_dir = "Food-11/validation/"
evaluation_dir = "Food-11/evaluation/"
num_classes = len(classes)

# %%
# training_dir = "Food-11/training/"
# training_images = os.listdir(training_dir)
# training_labels = np.array([int(f.split('_')[0]) for f in training_images ])

# %%
# validation_dir = "Food-11/validation/"
# validation_images = os.listdir(validation_dir)
# validation_labels = np.array([int(f.split('_')[0]) for f in validation_images ])

# %%
# evaluation_dir = "Food-11/evaluation/"
# evaluation_images = os.listdir(evaluation_dir)
# evaluation_labels = np.array([int(f.split('_')[0]) for f in evaluation_images ])

# %% [markdown]
# Let's look at a few random training samples:

# %%
# num_classes = len(classes)
# samples_per_class = 4
# figure = plt.figure(figsize=(num_classes*2,samples_per_class*2))
# for cls_idx, cls in enumerate(classes):
#   idxs = np.flatnonzero(training_labels == cls_idx)
#   idxs = np.random.choice(idxs, samples_per_class, replace=False)
#   for i, idx in enumerate(idxs):
#     plt_idx = i * num_classes + cls_idx + 1
#     plt.subplot(samples_per_class, num_classes, plt_idx)
#     im = Image.open(training_dir + training_images[idx])
#     plt.imshow(im)
#     plt.axis('off')
#     if i == 0:
#       plt.title(cls)
# plt.show()

# %% [markdown]
# We can see that two dessert samples (for example) may look very different from one another - intra-class variability. Furthermore, samples from two different classes, such as a rice dish and a noodles dish, may look very similar to one another - inter-class similarity.
#
# (In fact, some foods may really belong to multiple classes.  For example, fried chicken should really have both the "fried food" and "meat" labels, but only one class label is provided for each sample in the dataset.)

# %% [markdown]
# ## Prepare data directories

# %% [markdown]
# Because the Food-11 dataset is very large, we won't want to load the entire dataset into memory at once.
#
# Instead, Keras will let us read in images from disk as they are needed (in batches). For this to work, Keras [expects](https://keras.io/api/preprocessing/) that images will be organized in the following directory structure, with one subdirectory per class:
#
# ```
# main_directory/
# ...class_a/
# ......a_image_1.jpg
# ......a_image_2.jpg
# ...class_b/
# ......b_image_1.jpg
# ......b_image_2.jpg
# ```
#
# So, we will have to re-organize our directory structure to match.

# %%
# %cd $root_dir
# %cd ./content/Food-11/training/

# # loop over classes
# for i in range(len(classes)):
#   # make a directory for this class inside Food-11/training
#   try:
#     os.mkdir("class_%02d" % i)
#   except FileExistsError:
#     pass
#   # get list of files inside Food-11/training that have this class label
#   files = [f for f in os.listdir('.') if f.startswith("%d_" % i)]
#   # files = [f for f in os.listdir('/content/Food-11/training/') if f.startswith("%d_" % i)]
#   # move each file to the subdirectory for the class
#   for f in files:
#     shutil.move(f, "class_%02d/" % i)

# %%
# %cd $root_dir
# %cd ./content/Food-11/validation/

# for i in range(len(classes)):
#   try:
#     os.mkdir("class_%02d" % i)
#   except FileExistsError:
#     pass
#   files = [f for f in os.listdir('.') if f.startswith("%d_" % i)]
#   # files = [f for f in os.listdir('/content/Food-11/validation/') if f.startswith("%d_" % i)]
#   for f in files:
#     shutil.move(f, "class_%02d/" % i)

# %%
# %cd $root_dir
# %cd ./content/Food-11/evaluation/

# for i in range(len(classes)):
#   try:
#     os.mkdir("class_%02d" % i)
#   except FileExistsError:
#     pass
#   files = [f for f in os.listdir('.') if f.startswith("%d_" % i)]
#   # files = [f for f in os.listdir('/content/Food-11/evaluation/') if f.startswith("%d_" % i)]
#   for f in files:
#     shutil.move(f, "class_%02d/" % i)

# %%
# go back to default working directory
# %cd /content

# %% [markdown]
# Use the folder icon in Colab to look at your directory structure, and verify that within the training, validation, and evaluation data directories, there are subdirectories for each class containing the samples from that class.

# %% [markdown]
# ## Prepare data generators

# %% [markdown]
# Now that we have prepared the directory structure, we can set up our data "flow".

# %% [markdown]
# In the next cell, I have defined a batch size and an image size. You are free to change these parameters, or you can keep them. You can use any batch size that has good results in training, and you can change the input image size to match the input shape of whatever base model you are using.

# %%
# TODO 1 (optional) - design choice on batch size, image shape
BATCH_SIZE=32
INPUT_IMG_SIZE = 224

# %% [markdown]
# Then, I have defined some data generators to create augmented samples (slightly changed versions of the original samples). You are free to change the transformations used to generate the augmented data. You can learn more about the image transformations in the [ImageDataGenerator documentation](https://keras.io/api/preprocessing/image/#imagedatagenerator-class).
#
# After we define the data generator, we use  `flow_from_directory` to get images off the disk during training, on an as-needed basis.

# %%
AUTO = tf_data.AUTOTUNE
# %cd $root_dir

def preprocess_image(image, label):
    image = tf_image.resize(image, (INPUT_IMG_SIZE, INPUT_IMG_SIZE))
    image = tf_image.convert_image_dtype(image, "float32") / 255.0
    label = tf.keras.ops.cast(label, dtype="float32")
    return image, label

def gaussian_noise(np_arr):
    noise = tf.random_normal(shape=tf.shape(np_arr), mean=0.0, stddev=1.0,
    dtype=tf.float32)
    return tf.add(np_arr, noise)

training_aug = tf.keras.preprocessing.image.ImageDataGenerator(
  rescale=1.0/255,          # rescales so each pixel is in 0-1 range
	rotation_range=1,
	zoom_range=0.1,
	width_shift_range=0.1,
	height_shift_range=0.1,
	shear_range=0.1,
	horizontal_flip=True,
    brightness_range=(0.8, 1.2),
    preprocessing_function=gaussian_noise,
	fill_mode="nearest")

train_ds_one = training_aug.flow_from_directory(os.getcwd()+'/content/' + training_dir,
	target_size=(INPUT_IMG_SIZE, INPUT_IMG_SIZE),
	color_mode="rgb",
	shuffle=True,
	batch_size=BATCH_SIZE,
  class_mode='sparse')

train_ds_two = training_aug.flow_from_directory(os.getcwd()+'/content/' + training_dir,
	target_size=(INPUT_IMG_SIZE, INPUT_IMG_SIZE),
	color_mode="rgb",
	shuffle=True,
	batch_size=BATCH_SIZE,
  class_mode='sparse')

train_ds_one = tf.keras.preprocessing.image_dataset_from_directory()


# Combine two shuffled datasets from the same training data.
train_ds = tf_data.Dataset.zip((train_ds_one, train_ds_two))
# Out:
# D:\文档\NYU Classes\2023 Fall\ECE-GY 6143 Machine Learning\Lab 11
# Found 9866 images belonging to 11 classes.
# Found 9866 images belonging to 11 classes.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 43
#      34 train_ds_two = training_aug.flow_from_directory(os.getcwd()+'/content/' + training_dir,
#      35 	target_size=(INPUT_IMG_SIZE, INPUT_IMG_SIZE),
#      36 	color_mode="rgb",
#      37 	shuffle=True,
#      38 	batch_size=BATCH_SIZE,
#      39   class_mode='sparse')
#      42 # Combine two shuffled datasets from the same training data.
# ---> 43 train_ds = tf_data.Dataset.zip((train_ds_one, train_ds_two))
#
# File c:\Users\hower\.conda\envs\tf_gpu\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:1264, in DatasetV2.zip(datasets, name)
#    1218 @staticmethod
#    1219 def zip(datasets, name=None):
#    1220   """Creates a `Dataset` by zipping together the given datasets.
#    1221
#    1222   This method has similar semantics to the built-in `zip()` function
#    (...)
#    1262     Dataset: A `Dataset`.
#    1263   """
# -> 1264   return ZipDataset(datasets, name=name)
#
# File c:\Users\hower\.conda\envs\tf_gpu\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:4846, in ZipDataset.__init__(self, datasets, name)
#    4841       raise TypeError("Invalid `datasets`. `datasets` is expected to be a "
#    4842                       "(nested) structure of `tf.data.Dataset` objects. "
#    4843                       "Python `list` is not supported and you should use "
#    4844                       "`tuple` instead.")
#    4845     else:
# -> 4846       raise TypeError(f"Invalid `datasets`. `datasets` is expected to be a "
#    4847                       f"(nested) structure of `tf.data.Dataset` objects "
#    4848                       f"but encountered object of type {type(ds)}.")
#    4849 self._datasets = datasets
#    4850 self._structure = nest.pack_sequence_as(
#    4851     self._datasets,
#    4852     [ds.element_spec for ds in nest.flatten(self._datasets)])
#
# TypeError: Invalid `datasets`. `datasets` is expected to be a (nested) structure of `tf.data.Dataset` objects but encountered object of type <class 'keras.preprocessing.image.DirectoryIterator'>.

# %%
def sample_beta_distribution(size, concentration_0=0.2, concentration_1=0.2):
    gamma_1_sample = tf_random.gamma(shape=[size], alpha=concentration_1)
    gamma_2_sample = tf_random.gamma(shape=[size], alpha=concentration_0)
    return gamma_1_sample / (gamma_1_sample + gamma_2_sample)


def get_box(lambda_value):
    cut_rat = tf.keras.ops.sqrt(1.0 - lambda_value)

    cut_w = INPUT_IMG_SIZE * cut_rat  # rw
    cut_w = tf.keras.ops.cast(cut_w, "int32")

    cut_h = INPUT_IMG_SIZE * cut_rat  # rh
    cut_h = tf.keras.ops.cast(cut_h, "int32")

    cut_x = tf.keras.random.uniform((1,), minval=0, maxval=INPUT_IMG_SIZE)  # rx
    cut_x = tf.keras.ops.cast(cut_x, "int32")
    cut_y = tf.keras.random.uniform((1,), minval=0, maxval=INPUT_IMG_SIZE)  # ry
    cut_y = tf.keras.ops.cast(cut_y, "int32")

    boundaryx1 = clip_by_value(cut_x[0] - cut_w // 2, 0, INPUT_IMG_SIZE)
    boundaryy1 = clip_by_value(cut_y[0] - cut_h // 2, 0, INPUT_IMG_SIZE)
    bbx2 = clip_by_value(cut_x[0] + cut_w // 2, 0, INPUT_IMG_SIZE)
    bby2 = clip_by_value(cut_y[0] + cut_h // 2, 0, INPUT_IMG_SIZE)

    target_h = bby2 - boundaryy1
    if target_h == 0:
        target_h += 1

    target_w = bbx2 - boundaryx1
    if target_w == 0:
        target_w += 1

    return boundaryx1, boundaryy1, target_h, target_w


def cutmix(train_ds_one, train_ds_two):
    (image1, label1), (image2, label2) = train_ds_one, train_ds_two

    alpha = [0.25]
    beta = [0.25]

    # Get a sample from the Beta distribution
    lambda_value = sample_beta_distribution(1, alpha, beta)

    # Define Lambda
    lambda_value = lambda_value[0][0]

    # Get the bounding box offsets, heights and widths
    boundaryx1, boundaryy1, target_h, target_w = get_box(lambda_value)

    # Get a patch from the second image (`image2`)
    crop2 = tf_image.crop_to_bounding_box(
        image2, boundaryy1, boundaryx1, target_h, target_w
    )
    # Pad the `image2` patch (`crop2`) with the same offset
    image2 = tf_image.pad_to_bounding_box(
        crop2, boundaryy1, boundaryx1, INPUT_IMG_SIZE, INPUT_IMG_SIZE
    )
    # Get a patch from the first image (`image1`)
    crop1 = tf_image.crop_to_bounding_box(
        image1, boundaryy1, boundaryx1, target_h, target_w
    )
    # Pad the `image1` patch (`crop1`) with the same offset
    img1 = tf_image.pad_to_bounding_box(
        crop1, boundaryy1, boundaryx1, INPUT_IMG_SIZE, INPUT_IMG_SIZE
    )

    # Modify the first image by subtracting the patch from `image1`
    # (before applying the `image2` patch)
    image1 = image1 - img1
    # Add the modified `image1` and `image2`  together to get the CutMix image
    image = image1 + image2

    # Adjust Lambda in accordance to the pixel ration
    lambda_value = 1 - (target_w * target_h) / (INPUT_IMG_SIZE * INPUT_IMG_SIZE)
    lambda_value = tf.keras.ops.cast(lambda_value, "float32")

    # Combine the labels of both images
    label = lambda_value * label1 + (1 - lambda_value) * label2
    return image, label

# %%
# TODO 2 (optional) - design choices on image transformations for data augmentation
# %cd $root_dir
# prepare ImageDataGenerator to create augmented training samples


def gaussian_noise(np_arr):
    noise = tf.random_normal(shape=tf.shape(np_arr), mean=0.0, stddev=1.0,
    dtype=tf.float32)
    return tf.add(np_arr, noise)

training_aug = tf.keras.preprocessing.image.ImageDataGenerator(
  rescale=1.0/255,          # rescales so each pixel is in 0-1 range
	rotation_range=1,
	zoom_range=0.1,
	width_shift_range=0.1,
	height_shift_range=0.1,
	shear_range=0.1,
	horizontal_flip=True,
    brightness_range=(0.8, 1.2),
    preprocessing_function=gaussian_noise,
	fill_mode="nearest")

# prepare generator that pulls images from directory (and resizes)
training_gen = training_aug.flow_from_directory(
	os.getcwd()+'/content/' + training_dir,
	target_size=(INPUT_IMG_SIZE, INPUT_IMG_SIZE),
	color_mode="rgb",
	shuffle=True,
	batch_size=BATCH_SIZE,
  class_mode='sparse')
# training_gen = training_aug.flow_from_directory(
# 	'/content/' + training_dir,
# 	target_size=(INPUT_IMG_SIZE, INPUT_IMG_SIZE),
# 	color_mode="rgb",
# 	shuffle=True,
# 	batch_size=BATCH_SIZE,
#   class_mode='sparse')
# Out:
# D:\文档\NYU Classes\2023 Fall\ECE-GY 6143 Machine Learning\Lab 11
# Found 9866 images belonging to 11 classes.

# %% [markdown]
# Check the mapping of directory names to class labels:

# %%
training_gen.class_indices
# Out:
# {'class_00': 0,
#  'class_01': 1,
#  'class_02': 2,
#  'class_03': 3,
#  'class_04': 4,
#  'class_05': 5,
#  'class_06': 6,
#  'class_07': 7,
#  'class_08': 8,
#  'class_09': 9,
#  'class_10': 10}

# %% [markdown]
# We also set up the validation and evaluation (test) sets in a similar manner:

# %%
# %cd $root_dir

validation_aug = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1.0/255
)

validation_gen = validation_aug.flow_from_directory(
	os.getcwd()+'/content/' + validation_dir,
	target_size=(INPUT_IMG_SIZE, INPUT_IMG_SIZE),
	color_mode="rgb",
	shuffle=True,
	batch_size=BATCH_SIZE,
  class_mode='sparse')
# validation_gen = validation_aug.flow_from_directory(
# 	'/content/' + validation_dir,
# 	target_size=(INPUT_IMG_SIZE, INPUT_IMG_SIZE),
# 	color_mode="rgb",
# 	shuffle=True,
# 	batch_size=BATCH_SIZE,
#   class_mode='sparse')
# Out:
# D:\文档\NYU Classes\2023 Fall\ECE-GY 6143 Machine Learning\Lab 11
# Found 3430 images belonging to 11 classes.

# %% [markdown]
# Don't shuffle the evaluation set:

# %%
# %cd $root_dir

evaluation_aug = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1.0/255
)

evaluation_gen = evaluation_aug.flow_from_directory(
	os.getcwd()+'/content/' + evaluation_dir,
	target_size=(INPUT_IMG_SIZE, INPUT_IMG_SIZE),
	color_mode="rgb",
	shuffle=False,
	batch_size=BATCH_SIZE,
  class_mode='sparse')

# evaluation_gen = evaluation_aug.flow_from_directory(
# 	'/content/' + evaluation_dir,
# 	target_size=(INPUT_IMG_SIZE, INPUT_IMG_SIZE),
# 	color_mode="rgb",
# 	shuffle=False,
# 	batch_size=BATCH_SIZE,
#   class_mode='sparse')
# Out:
# D:\文档\NYU Classes\2023 Fall\ECE-GY 6143 Machine Learning\Lab 11
# Found 3347 images belonging to 11 classes.

# %% [markdown]
# ## Prepare base model

# %% [markdown]
# Now that the data is ready, we need to prepare the model.

# %% [markdown]
# First, review the models available as [Keras Applications](https://keras.io/api/applications/), and decide which model you will use. Make sure to click through from the table to the model documentation, to learn more about each model you are considering.

# %% [markdown]
# In the cell that follows, I have used the [VGG16](https://keras.io/api/applications/vgg/) model, but you can change that - you may use any model that you think will have good results.

# %%
# TODO 3 (optional) - design choice on base model

# base_model = tf.keras.applications.VGG16(
#   input_shape=(INPUT_IMG_SIZE,INPUT_IMG_SIZE,3),
#   include_top=False,
#   pooling='avg'
# )
base_model = tf.keras.applications.MobileNet(
    input_shape=(INPUT_IMG_SIZE,INPUT_IMG_SIZE,3),
    include_top=False,
    pooling='avg'
)

# %%
base_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train model with new classification head

# %% [markdown]
# In the following cell, "freeze" your base model (set it so that it is not trainable), and then construct a new model using the frozen base model with a new classification head.  (You can add a dropout layer in between if you think it will be helpful.)
#
# (You can refer to this week's demo notebook for an example.)

# %%
# TODO 4 (required) - prepare model with new classification head
base_model.trainable=False
model = tf.keras.models.Sequential()
# add to your model here...

model.add(base_model)
# model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dropout(0.1))
model.add(tf.keras.layers.Dense(
    units=num_classes,
    activation=tf.keras.activations.softmax
))

# %% [markdown]
# Then, print a model summary:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 11)                5643
#
# =================================================================
# Total params: 14,720,331
# Trainable params: 5,643
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# (Make sure that most parameters are "non-trainable", because you have frozen the base model!)

# %% [markdown]
# Compile your model with an appropriate optimizer and loss function, and use accuracy as a metric.

# %%
# TODO 5 (required) - design training parameters, and compile

# model.compile(...)
opt = tf.keras.optimizers.Adam(learning_rate=0.001) # 0.001 0.002 0.004 0.008 0.016
model.compile(
    optimizer=opt,
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=['accuracy']
)

# %% [markdown]
# Finally, fit your model with the new classification head for as many epochs as you think is appropriate. You may also use early stopping if you think it will be helpful.
#
# Pass the validation data generator as `validation_data`.
#
# (You can refer to this week's demo notebook for an example.)

# %%
from tensorflow.keras import callbacks

class TrainStats(callbacks.Callback):

    def __init__(self):
        self.best_train_acc = 0.0
        self.best_train_loss = 0.0
        self.best_val_acc = 0.0
        self.best_val_loss = 0.0
        self.best_epoch = 0

    def on_epoch_end(self, epoch, logs=None):
        val_acc = logs.get("val_accuracy")
        if val_acc > self.best_val_acc:
            self.best_val_acc = val_acc
            self.best_epoch = epoch

        train_acc = logs.get("accuracy")
        if train_acc > self.best_train_acc:
            self.best_train_acc = train_acc  

        val_loss = logs.get("val_loss")
        if val_loss > self.best_val_loss:
            self.best_val_loss = val_loss
            
        train_loss = logs.get("loss")
        if train_loss > self.best_train_loss:
            self.best_train_acc = train_loss

        print(f"""Best Stats:
              Train acc: {self.best_train_acc:.4f}\tTrain loss: {self.best_train_loss:.4f}
              Val acc:   {self.best_val_acc:.4f}\tVal loss:   {self.best_val_loss:.4f}
              Epoch: {self.best_epoch}\tLearning rate:{self.model.optimizer.lr.numpy():.4e}""")

        # if conditions are met..
        # self.model.stop_training = True

# %%
checkpoint_path = "checkpoint/cp_{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path, save_weights_only=True, verbose=1)
backup_callback = tf.keras.callbacks.BackupAndRestore(backup_dir="./backup", delete_checkpoint=True)
early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",
                                                           min_delta=0.001,
                                                           patience=5,
                                                           restore_best_weights=True,
                                                           verbose=1)
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * np.exp(-0.05)
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=0)

# %%
# TODO 6 (required) - fit model, you decide how many epochs
# note: you can get the number of training samples with training_gen.n
# and the number of validation samples with validation_gen.n
# n_epochs = ...
# hist = model.fit(...)
n_epochs = 100
K.clear_session()
hist = model.fit(x=training_gen, 
                 epochs=n_epochs,
                 validation_data=validation_gen, 
                 batch_size=BATCH_SIZE, 
                 callbacks=[cp_callback, 
                            early_stopping_callback,
                            lr_scheduler,
                            ])
# hist = model.fit(x=training_gen, epochs=n_epochs, batch_size=BATCH_SIZE)
# Out:
# Epoch 1/100
# 309/309 [==============================] - ETA: 0s - loss: 1.9864 - accuracy: 0.3382
# Epoch 1: saving model to checkpoint\cp_0001.ckpt
# 309/309 [==============================] - 138s 374ms/step - loss: 1.9864 - accuracy: 0.3382 - val_loss: 1.6945 - val_accuracy: 0.4536 - lr: 0.0010
# Epoch 2/100
# 309/309 [==============================] - ETA: 0s - loss: 1.6134 - accuracy: 0.4874
# Epoch 2: saving model to checkpoint\cp_0002.ckpt
# 309/309 [==============================] - 73s 236ms/step - loss: 1.6134 - accuracy: 0.4874 - val_loss: 1.4733 - val_accuracy: 0.5318 - lr: 0.0010
# Epoch 3/100
# 309/309 [==============================] - ETA: 0s - loss: 1.4549 - accuracy: 0.5340
# Epoch 3: saving model to checkpoint\cp_0003.ckpt
# 309/309 [==============================] - 153s 494ms/step - loss: 1.4549 - accuracy: 0.5340 - val_loss: 1.3614 - val_accuracy: 0.5621 - lr: 0.0010
# Epoch 4/100
# 309/309 [==============================] - ETA: 0s - loss: 1.3591 - accuracy: 0.5649
# Epoch 4: saving model to checkpoint\cp_0004.ckpt
# 309/309 [==============================] - 196s 635ms/step - loss: 1.3591 - accuracy: 0.5649 - val_loss: 1.3005 - val_accuracy: 0.5764 - lr: 0.0010
# Epoch 5/100
# 309/309 [==============================] - ETA: 0s - loss: 1.2953 - accuracy: 0.5808
# Epoch 5: saving model to checkpoint\cp_0005.ckpt
# 309/309 [==============================] - 118s 381ms/step - loss: 1.2953 - accuracy: 0.5808 - val_loss: 1.2405 - val_accuracy: 0.5936 - lr: 0.0010
# Epoch 6/100
# 309/309 [==============================] - ETA: 0s - loss: 1.2449 - accuracy: 0.5975
# Epoch 6: saving model to checkpoint\cp_0006.ckpt
# 309/309 [==============================] - 80s 259ms/step - loss: 1.2449 - accuracy: 0.5975 - val_loss: 1.1972 - val_accuracy: 0.6067 - lr: 0.0010
# Epoch 7/100
# 309/309 [==============================] - ETA: 0s - loss: 1.2145 - accuracy: 0.6033
# Epoch 7: saving model to checkpoint\cp_0007.ckpt
# 309/309 [==============================] - 128s 416ms/step - loss: 1.2145 - accuracy: 0.6033 - val_loss: 1.1714 - val_accuracy: 0.6187 - lr: 0.0010
# Epoch 8/100
# 309/309 [==============================] - ETA: 0s - loss: 1.1862 - accuracy: 0.6113
# Epoch 8: saving model to checkpoint\cp_0008.ckpt
# 309/309 [==============================] - 738s 2s/step - loss: 1.1862 - accuracy: 0.6113 - val_loss: 1.1571 - val_accuracy: 0.6210 - lr: 0.0010
# Epoch 9/100
# 309/309 [==============================] - ETA: 0s - loss: 1.1538 - accuracy: 0.6202
# Epoch 9: saving model to checkpoint\cp_0009.ckpt
# 309/309 [==============================] - 128s 415ms/step - loss: 1.1538 - accuracy: 0.6202 - val_loss: 1.1297 - val_accuracy: 0.6259 - lr: 0.0010
# Epoch 10/100
# 309/309 [==============================] - ETA: 0s - loss: 1.1334 - accuracy: 0.6290
# Epoch 10: saving model to checkpoint\cp_0010.ckpt
# 309/309 [==============================] - 123s 399ms/step - loss: 1.1334 - accuracy: 0.6290 - val_loss: 1.1139 - val_accuracy: 0.6385 - lr: 0.0010
# Epoch 11/100
# 309/309 [==============================] - ETA: 0s - loss: 1.1169 - accuracy: 0.6304
# Epoch 11: saving model to checkpoint\cp_0011.ckpt
# 309/309 [==============================] - 132s 427ms/step - loss: 1.1169 - accuracy: 0.6304 - val_loss: 1.0925 - val_accuracy: 0.6388 - lr: 9.5123e-04
# Epoch 12/100
# 309/309 [==============================] - ETA: 0s - loss: 1.1090 - accuracy: 0.6326
# Epoch 12: saving model to checkpoint\cp_0012.ckpt
# 309/309 [==============================] - 175s 566ms/step - loss: 1.1090 - accuracy: 0.6326 - val_loss: 1.0786 - val_accuracy: 0.6385 - lr: 9.0484e-04
# Epoch 13/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0933 - accuracy: 0.6357
# Epoch 13: saving model to checkpoint\cp_0013.ckpt
# 309/309 [==============================] - 131s 425ms/step - loss: 1.0933 - accuracy: 0.6357 - val_loss: 1.0755 - val_accuracy: 0.6510 - lr: 8.6071e-04
# Epoch 14/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0825 - accuracy: 0.6451
# Epoch 14: saving model to checkpoint\cp_0014.ckpt
# 309/309 [==============================] - 280s 906ms/step - loss: 1.0825 - accuracy: 0.6451 - val_loss: 1.0689 - val_accuracy: 0.6475 - lr: 8.1873e-04
# Epoch 15/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0739 - accuracy: 0.6432
# Epoch 15: saving model to checkpoint\cp_0015.ckpt
# 309/309 [==============================] - 129s 419ms/step - loss: 1.0739 - accuracy: 0.6432 - val_loss: 1.0580 - val_accuracy: 0.6493 - lr: 7.7880e-04
# Epoch 16/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0649 - accuracy: 0.6462
# Epoch 16: saving model to checkpoint\cp_0016.ckpt
# 309/309 [==============================] - 131s 423ms/step - loss: 1.0649 - accuracy: 0.6462 - val_loss: 1.0455 - val_accuracy: 0.6528 - lr: 7.4082e-04
# Epoch 17/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0618 - accuracy: 0.6469
# Epoch 17: saving model to checkpoint\cp_0017.ckpt
# 309/309 [==============================] - 130s 419ms/step - loss: 1.0618 - accuracy: 0.6469 - val_loss: 1.0468 - val_accuracy: 0.6534 - lr: 7.0469e-04
# Epoch 18/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0525 - accuracy: 0.6490
# Epoch 18: saving model to checkpoint\cp_0018.ckpt
# 309/309 [==============================] - 131s 423ms/step - loss: 1.0525 - accuracy: 0.6490 - val_loss: 1.0377 - val_accuracy: 0.6598 - lr: 6.7032e-04
# Epoch 19/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0506 - accuracy: 0.6488
# Epoch 19: saving model to checkpoint\cp_0019.ckpt
# 309/309 [==============================] - 131s 424ms/step - loss: 1.0506 - accuracy: 0.6488 - val_loss: 1.0275 - val_accuracy: 0.6598 - lr: 6.3763e-04
# Epoch 20/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0454 - accuracy: 0.6486
# Epoch 20: saving model to checkpoint\cp_0020.ckpt
# 309/309 [==============================] - 813s 3s/step - loss: 1.0454 - accuracy: 0.6486 - val_loss: 1.0250 - val_accuracy: 0.6647 - lr: 6.0653e-04
# Epoch 21/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0405 - accuracy: 0.6473
# Epoch 21: saving model to checkpoint\cp_0021.ckpt
# 309/309 [==============================] - 351s 1s/step - loss: 1.0405 - accuracy: 0.6473 - val_loss: 1.0214 - val_accuracy: 0.6606 - lr: 5.7695e-04
# Epoch 22/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0401 - accuracy: 0.6503
# Epoch 22: saving model to checkpoint\cp_0022.ckpt
# 309/309 [==============================] - 128s 413ms/step - loss: 1.0401 - accuracy: 0.6503 - val_loss: 1.0274 - val_accuracy: 0.6606 - lr: 5.4881e-04
# Epoch 23/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0310 - accuracy: 0.6573
# Epoch 23: saving model to checkpoint\cp_0023.ckpt
# 309/309 [==============================] - 127s 413ms/step - loss: 1.0310 - accuracy: 0.6573 - val_loss: 1.0187 - val_accuracy: 0.6633 - lr: 5.2205e-04
# Epoch 24/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0224 - accuracy: 0.6612
# Epoch 24: saving model to checkpoint\cp_0024.ckpt
# 309/309 [==============================] - 127s 411ms/step - loss: 1.0224 - accuracy: 0.6612 - val_loss: 1.0179 - val_accuracy: 0.6668 - lr: 4.9659e-04
# Epoch 25/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0257 - accuracy: 0.6551
# Epoch 25: saving model to checkpoint\cp_0025.ckpt
# 309/309 [==============================] - 114s 370ms/step - loss: 1.0257 - accuracy: 0.6551 - val_loss: 1.0139 - val_accuracy: 0.6668 - lr: 4.7237e-04
# Epoch 26/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0188 - accuracy: 0.6631
# Epoch 26: saving model to checkpoint\cp_0026.ckpt
# 309/309 [==============================] - 113s 367ms/step - loss: 1.0188 - accuracy: 0.6631 - val_loss: 1.0082 - val_accuracy: 0.6703 - lr: 4.4933e-04
# Epoch 27/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0190 - accuracy: 0.6572
# Epoch 27: saving model to checkpoint\cp_0027.ckpt
# 309/309 [==============================] - 127s 412ms/step - loss: 1.0190 - accuracy: 0.6572 - val_loss: 1.0078 - val_accuracy: 0.6662 - lr: 4.2741e-04
# Epoch 28/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0154 - accuracy: 0.6585
# Epoch 28: saving model to checkpoint\cp_0028.ckpt
# 309/309 [==============================] - 127s 412ms/step - loss: 1.0154 - accuracy: 0.6585 - val_loss: 1.0087 - val_accuracy: 0.6685 - lr: 4.0657e-04
# Epoch 29/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0117 - accuracy: 0.6662
# Epoch 29: saving model to checkpoint\cp_0029.ckpt
# 309/309 [==============================] - 128s 414ms/step - loss: 1.0117 - accuracy: 0.6662 - val_loss: 1.0040 - val_accuracy: 0.6720 - lr: 3.8674e-04
# Epoch 30/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0104 - accuracy: 0.6636
# Epoch 30: saving model to checkpoint\cp_0030.ckpt
# 309/309 [==============================] - 127s 410ms/step - loss: 1.0104 - accuracy: 0.6636 - val_loss: 0.9980 - val_accuracy: 0.6738 - lr: 3.6788e-04
# Epoch 31/100
# 309/309 [==============================] - ETA: 0s - loss: 0.9947 - accuracy: 0.6684
# Epoch 31: saving model to checkpoint\cp_0031.ckpt
# 309/309 [==============================] - 128s 414ms/step - loss: 0.9947 - accuracy: 0.6684 - val_loss: 0.9999 - val_accuracy: 0.6694 - lr: 3.4994e-04
# Epoch 32/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0049 - accuracy: 0.6622
# Epoch 32: saving model to checkpoint\cp_0032.ckpt
# 309/309 [==============================] - 114s 369ms/step - loss: 1.0049 - accuracy: 0.6622 - val_loss: 0.9996 - val_accuracy: 0.6665 - lr: 3.3287e-04
# Epoch 33/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0004 - accuracy: 0.6651
# Epoch 33: saving model to checkpoint\cp_0033.ckpt
# 309/309 [==============================] - 131s 423ms/step - loss: 1.0004 - accuracy: 0.6651 - val_loss: 0.9960 - val_accuracy: 0.6732 - lr: 3.1664e-04
# Epoch 34/100
# 309/309 [==============================] - ETA: 0s - loss: 1.0041 - accuracy: 0.6648
# Epoch 34: saving model to checkpoint\cp_0034.ckpt
# 309/309 [==============================] - 410s 1s/step - loss: 1.0041 - accuracy: 0.6648 - val_loss: 0.9983 - val_accuracy: 0.6720 - lr: 3.0119e-04
# Epoch 35/100
# 309/309 [==============================] - ETA: 0s - loss: 0.9975 - accuracy: 0.6645
# Epoch 35: saving model to checkpoint\cp_0035.ckpt
# Restoring model weights from the end of the best epoch: 30.
# 309/309 [==============================] - 113s 364ms/step - loss: 0.9975 - accuracy: 0.6645 - val_loss: 0.9935 - val_accuracy: 0.6743 - lr: 2.8650e-04
# Epoch 35: early stopping

# %%
model.save('vgg_basic.keras')
np.save('hist.npy',hist.history) # in case of kernel crashing

# %% [markdown]
# Plot the training history. In one subplot, show loss vs. epoch for the training and validation sets on the same plot. In the second subplot, show accuracy vs. epoch for the training and validation sets on the same plot.

# %% [markdown]
# Make sure you show the training history from the *beginning* of training. (If you re-run the `hist = fit(...)` command, you'll overwrite the previous history and lose the training history from the beginning, so be careful not to do that in your final submission!)

# %%
# TODO 7 (required) - plot training history
# Accessing training and validation loss values from history
try:
    tr_loss = hist.history['loss']
    tr_acc = hist.history['accuracy']
    val_loss = hist.history['val_loss']
    val_acc = hist.history['val_accuracy']
except NameError:
    history_loaded=np.load('hist.npy',allow_pickle='TRUE').item()
    tr_loss = history_loaded['loss']
    tr_acc = history_loaded['accuracy']
    val_loss = history_loaded['val_loss']
    val_acc = history_loaded['val_accuracy']

epochs = range(1, len(tr_loss) + 1)

# Visualizing training and validation loss
plt.figure(figsize=(15,6))

plt.subplot(1,2,1)
plt.plot(epochs, tr_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs, tr_acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Fine-tune model

# %% [markdown]
# Next, we are going to "un-freeze" the later layers of the model, and train it for a few more epochs on our data (with a smaller learning rate), so that it is better suited for our specific classification task.

# %% [markdown]
# Note that you should *not* create a new model. We're just going to continue training the model we already started training.

# %% [markdown]
# First, we will un-freeze the base model:

# %%
# Load model
model = tf.keras.models.load_model('vgg_basic.keras')

# %%
base_model.trainable = True

# %% [markdown]
# Then, we will re-freeze only the first layers of the base model. In the cell below, I have left the last five layers, which includes the last set of convolutional filters, unfrozen. But you are free to change this number if you think you will get better performance.

# %%
# TODO 8 (optional) - you can decide how many layers to unfreeze

for layer in base_model.layers[:-6]:
	layer.trainable = False

# %% [markdown]
# The output of the following cell will indicate which layers in the base model are trainable, and which are not:

# %%
for layer in base_model.layers:
  print("{}: {}".format(layer, layer.trainable))
# Out:
# <keras.engine.input_layer.InputLayer object at 0x000001D5F6175460>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5F61849A0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5F6184CD0>: False
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001D5F69764C0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5F6184FD0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5929D25E0>: False
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001D5929D2E80>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5F69B2F40>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5929E2970>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5929E2C70>: False
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001D5929EB610>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5929DDA90>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5929F23A0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5929F2B50>: False
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001D5929F9EB0>: True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5929F2AC0>: True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5929F9490>: True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001D5929FF7F0>: True
# <keras.layers.pooling.max_pooling2d.MaxPooling2D object at 0x000001D592A0F7C0>: True
# <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D object at 0x000001D592A0F790>: True

# %% [markdown]
# Also, the model summary should now show more trainable parameters:

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 11)                5643
#
# =================================================================
# Total params: 14,720,331
# Trainable params: 5,643
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# Re-compile your model. Don't forget to use a smaller learning rate for fine-tuning! We don't want to make major changes to the last feature extraction layers, we just want to adjust them a little bit.

# %%
# TODO 9 (required) - re-compile model
# use a smaller learning rate for fine-tuning
try:
    first_lr = hist.history['lr'][0]
    last_lr = hist.history['lr'][-1]
except NameError:
    first_lr = history_loaded['lr'][0]
    last_lr = history_loaded['lr'][-1]
ft_lr = first_lr * 0.01
print("Learning rate decay from", first_lr, "to", last_lr)
print("Fine tune learning rate:", ft_lr)
# model.compile(...)
opt = tf.keras.optimizers.Adam(learning_rate=ft_lr)
model.compile(
    optimizer=opt,
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=['accuracy']
)
print(model.optimizer.lr.numpy())
# Out:
# Learning rate decay from 0.001 to 0.00028650483
# Fine tune learning rate: 1.0000000474974514e-05
# 1.0000000474974514e-05

# %% [markdown]
# Fit your model (with some newly unfrozen layers) for some more epochs.

# %%
ft_early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",
                                                           min_delta=0.0001,
                                                           patience=5,
                                                           restore_best_weights=True)
def ft_scheduler(epoch, lr):
    if epoch < 20:
        return lr
    # elif 10 <= epoch < 20:
    #     return lr * np.exp(-0.05)
    else:
        return lr * np.exp(-0.05)
ft_lr_scheduler = tf.keras.callbacks.LearningRateScheduler(ft_scheduler, verbose=0)

# %%
# TODO 10 (required) - fit model, you decide how many epochs
# note: you can get the number of training samples with training_gen.n
# and the number of validation samples with validation_gen.n

# n_epochs_fine = ...
# hist_fine = model.fit(...)
n_epochs_fine = 200
# FT_BATCH_SIZE = 0.75 * BATCH_SIZE
hist_fine = model.fit(x=training_gen, 
                    epochs=n_epochs_fine,
                    validation_data=validation_gen, 
                    batch_size=BATCH_SIZE, 
                    callbacks=[cp_callback, 
                              #  TrainStats(),
                               ft_early_stopping_callback,
                               ft_lr_scheduler,
                            #    backup_callback
                               ])
# Out:
# Epoch 1/200
# 309/309 [==============================] - ETA: 0s - loss: 1.0075 - accuracy: 0.6644
# Epoch 1: saving model to checkpoint\cp_0001.ckpt
# 309/309 [==============================] - 75s 243ms/step - loss: 1.0075 - accuracy: 0.6644 - val_loss: 0.9975 - val_accuracy: 0.6738 - lr: 1.0000e-05
# Epoch 2/200
# 309/309 [==============================] - ETA: 0s - loss: 0.9976 - accuracy: 0.6684
# Epoch 2: saving model to checkpoint\cp_0002.ckpt
# 309/309 [==============================] - 108s 350ms/step - loss: 0.9976 - accuracy: 0.6684 - val_loss: 0.9975 - val_accuracy: 0.6752 - lr: 1.0000e-05
# Epoch 3/200
# 309/309 [==============================] - ETA: 0s - loss: 1.0015 - accuracy: 0.6680
# Epoch 3: saving model to checkpoint\cp_0003.ckpt
# 309/309 [==============================] - 106s 343ms/step - loss: 1.0015 - accuracy: 0.6680 - val_loss: 0.9976 - val_accuracy: 0.6746 - lr: 1.0000e-05
# Epoch 4/200
# 309/309 [==============================] - ETA: 0s - loss: 1.0076 - accuracy: 0.6575
# Epoch 4: saving model to checkpoint\cp_0004.ckpt
# 309/309 [==============================] - 130s 421ms/step - loss: 1.0076 - accuracy: 0.6575 - val_loss: 0.9978 - val_accuracy: 0.6741 - lr: 1.0000e-05
# Epoch 5/200
# 309/309 [==============================] - ETA: 0s - loss: 1.0021 - accuracy: 0.6639
# Epoch 5: saving model to checkpoint\cp_0005.ckpt
# 309/309 [==============================] - 86s 276ms/step - loss: 1.0021 - accuracy: 0.6639 - val_loss: 0.9980 - val_accuracy: 0.6723 - lr: 1.0000e-05
# Epoch 6/200
# 309/309 [==============================] - ETA: 0s - loss: 1.0030 - accuracy: 0.6648
# Epoch 6: saving model to checkpoint\cp_0006.ckpt
# 309/309 [==============================] - 383s 1s/step - loss: 1.0030 - accuracy: 0.6648 - val_loss: 0.9981 - val_accuracy: 0.6726 - lr: 1.0000e-05
# Epoch 7/200
# 309/309 [==============================] - ETA: 0s - loss: 0.9937 - accuracy: 0.6696
# Epoch 7: saving model to checkpoint\cp_0007.ckpt
# 309/309 [==============================] - 471s 2s/step - loss: 0.9937 - accuracy: 0.6696 - val_loss: 0.9982 - val_accuracy: 0.6714 - lr: 1.0000e-05

# %%
model.save('vgg16_fine_tune.keras')
np.save('vgg16_hist_fine.npy',hist_fine.history) # in case of crashing

# %% [markdown]
# Plot the complete training history. In one subplot, show loss vs. epoch for the training and validation sets on the same plot. In the second subplot, show accuracy vs. epoch for the training and validation sets on the same plot. Draw a vertical line demarcating the first stage of training (training the classification head) and the second stage of training (fine tuning).
#
# (You can refer to this week's demo notebook for an example.)

# %% [markdown]
# Make sure you show the training history from the *beginning* of training. (If you re-run the `hist_fine = fit(...)` command, you'll overwrite the previous history and lose the training history from the beginning, so be careful not to do that in your final submission!)

# %%
# TODO 11 (required) - plot training history
try:
    tr_loss = hist.history['loss']
    tr_acc = hist.history['accuracy']
    val_loss = hist.history['val_loss']
    val_acc = hist.history['val_accuracy']
except NameError:
    history_loaded=np.load('hist.npy',allow_pickle='TRUE').item()
    tr_loss = history_loaded['loss']
    tr_acc = history_loaded['accuracy']
    val_loss = history_loaded['val_loss']
    val_acc = history_loaded['val_accuracy']
border = len(tr_loss)
ft_tr_loss = tr_loss + hist_fine.history['loss']
ft_tr_acc = tr_acc + hist_fine.history['accuracy']
ft_val_loss = val_loss + hist_fine.history['val_loss']
ft_val_acc = val_acc + hist_fine.history['val_accuracy']
epochs = range(1, len(ft_tr_loss) + 1)

# Visualizing training and validation loss
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.axvline(x=border, color='red', linestyle='--', label='')
plt.plot(epochs, ft_tr_loss, label='Training Loss')
plt.plot(epochs, ft_val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.axvline(x=border, color='red', linestyle='--', label='')
plt.plot(epochs, ft_tr_acc, label='Training Accuracy')
plt.plot(epochs, ft_val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Fine-tuning stage II

# %%
model = tf.keras.models.load_model('fine_tune.keras')

# %%
base_model.trainable = True
# unfreeze the last 14 layers (was 7 layers)
for layer in base_model.layers[:-14]:
	layer.trainable = False

# %%
for layer in base_model.layers:
  print("{}: {}".format(layer, layer.trainable))

model.summary()
# Out:
# <keras.engine.input_layer.InputLayer object at 0x000001B7DB906430>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B7CD772250>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B7DB917790>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B7DB917670>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788ECF2E0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788EE0D00>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788EE0CD0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788EF7D90>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788EF7550>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F0D5E0>: False
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x000001B788EF7EE0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F10C70>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F17D00>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F1D700>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F172E0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F1D8B0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F296A0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F298B0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F2FFD0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F369D0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F36250>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F360A0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F4A160>: False
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x000001B788F3EFD0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F436A0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F4FFD0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F589D0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F4F5E0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F4F460>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F29790>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F254F0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F06670>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B7DC10ED00>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788ECFFA0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F62520>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F66310>: False
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x000001B788F66FD0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F68580>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F6B550>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788ECFFD0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F66850>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F68A00>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F71E20>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F7D490>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F817F0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F871F0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F87190>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F87C70>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F955E0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F90A00>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F9BF70>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FAB040>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788FAB550>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FAB340>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FB3100>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788FB3B80>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FBB7C0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FC2250>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788FC2F40>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FC2A60>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FB3FD0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788FCA6D0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FD6EB0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FE61F0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788FE61C0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FE6C40>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FB3190>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788FAB5B0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FD6F10>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F81220>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F7D2E0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F7D100>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F877C0>: False
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x000001B788F4F070>: True
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788FE9550>: True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FEB460>: True
# <keras.layers.activation.relu.ReLU object at 0x000001B788F663D0>: True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788FEB070>: True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FE96D0>: True
# <keras.layers.activation.relu.ReLU object at 0x000001B78CFC1160>: True
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B78CFC1BE0>: True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B78CFC3730>: True
# <keras.layers.activation.relu.ReLU object at 0x000001B78CFCA130>: True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B78CFCAFD0>: True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B78CFCAAF0>: True
# <keras.layers.activation.relu.ReLU object at 0x000001B78CFD54F0>: True
# <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D object at 0x000001B78CFD08B0>: True
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 1024)             3228864
#  nal)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 11)                11275
#
# =================================================================
# Total params: 3,240,139
# Trainable params: 1,073,163
# Non-trainable params: 2,166,976
# _________________________________________________________________

# %%
first_ft_lr = hist_fine.history['lr'][0]
last_ft_lr = hist_fine.history['lr'][-1]
try:
    first_ft_lr = hist_fine.history['lr'][0]
    last_ft_lr = hist_fine.history['lr'][-1]
except NameError:
    first_ft_lr = history_loaded['lr'][0]
    last_ft_lr = history_loaded['lr'][-1]
second_ft_lr = first_ft_lr*1/2
print("First fine tuning learning rate decay from", first_ft_lr, "to", last_ft_lr)
print("Second fine tuning learning rate:", second_ft_lr)
# model.compile(...)
opt = tf.keras.optimizers.Adam(learning_rate=second_ft_lr)
model.compile(
    optimizer=opt,
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=['accuracy']
)
# Out:
# First fine tuning learning rate decay from 1.0000000474974514e-05 to 6.703200778741331e-06
# Second fine tuning learning rate: 5.000000237487257e-06

# %%
ft2_early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",
                                                           min_delta=0.001,
                                                           patience=10,
                                                           restore_best_weights=True)
def ft2_scheduler(epoch, lr):
    if epoch < 20:
        return lr
    else:
        return lr * np.exp(-0.05)
ft2_lr_scheduler = tf.keras.callbacks.LearningRateScheduler(ft2_scheduler, verbose=0)

# %%
n_epochs_fine2 = 200
hist_fine_2 = model.fit(x=training_gen, 
                    epochs=n_epochs_fine2,
                    validation_data=validation_gen, 
                    batch_size=BATCH_SIZE, 
                    callbacks=[cp_callback, 
                               ft2_early_stopping_callback,
                               ft2_lr_scheduler])
model.save('fine_tune_2.keras')
np.save('hist_fine_2.npy',hist_fine_2.history)
# Out:
# Epoch 1/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2462 - accuracy: 0.9163
# Epoch 1: saving model to checkpoint\cp_0001.ckpt
# 309/309 [==============================] - 79s 252ms/step - loss: 0.2462 - accuracy: 0.9163 - val_loss: 0.4958 - val_accuracy: 0.8472 - lr: 5.0000e-06
# Epoch 2/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.9102
# Epoch 2: saving model to checkpoint\cp_0002.ckpt
# 309/309 [==============================] - 74s 239ms/step - loss: 0.2544 - accuracy: 0.9102 - val_loss: 0.4956 - val_accuracy: 0.8472 - lr: 5.0000e-06
# Epoch 3/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2432 - accuracy: 0.9160
# Epoch 3: saving model to checkpoint\cp_0003.ckpt
# 309/309 [==============================] - 73s 237ms/step - loss: 0.2432 - accuracy: 0.9160 - val_loss: 0.4934 - val_accuracy: 0.8469 - lr: 5.0000e-06
# Epoch 4/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9174
# Epoch 4: saving model to checkpoint\cp_0004.ckpt
# 309/309 [==============================] - 73s 237ms/step - loss: 0.2372 - accuracy: 0.9174 - val_loss: 0.4938 - val_accuracy: 0.8464 - lr: 5.0000e-06
# Epoch 5/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9230
# Epoch 5: saving model to checkpoint\cp_0005.ckpt
# 309/309 [==============================] - 73s 237ms/step - loss: 0.2286 - accuracy: 0.9230 - val_loss: 0.4925 - val_accuracy: 0.8481 - lr: 5.0000e-06
# Epoch 6/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2402 - accuracy: 0.9148
# Epoch 6: saving model to checkpoint\cp_0006.ckpt
# 309/309 [==============================] - 73s 236ms/step - loss: 0.2402 - accuracy: 0.9148 - val_loss: 0.4923 - val_accuracy: 0.8487 - lr: 5.0000e-06
# Epoch 7/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2235 - accuracy: 0.9222
# Epoch 7: saving model to checkpoint\cp_0007.ckpt
# 309/309 [==============================] - 73s 238ms/step - loss: 0.2235 - accuracy: 0.9222 - val_loss: 0.4895 - val_accuracy: 0.8481 - lr: 5.0000e-06
# Epoch 8/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2258 - accuracy: 0.9246
# Epoch 8: saving model to checkpoint\cp_0008.ckpt
# 309/309 [==============================] - 73s 236ms/step - loss: 0.2258 - accuracy: 0.9246 - val_loss: 0.4917 - val_accuracy: 0.8478 - lr: 5.0000e-06
# Epoch 9/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2251 - accuracy: 0.9244
# Epoch 9: saving model to checkpoint\cp_0009.ckpt
# 309/309 [==============================] - 73s 236ms/step - loss: 0.2251 - accuracy: 0.9244 - val_loss: 0.4931 - val_accuracy: 0.8484 - lr: 5.0000e-06
# Epoch 10/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2199 - accuracy: 0.9241
# Epoch 10: saving model to checkpoint\cp_0010.ckpt
# 309/309 [==============================] - 74s 238ms/step - loss: 0.2199 - accuracy: 0.9241 - val_loss: 0.4919 - val_accuracy: 0.8478 - lr: 5.0000e-06
# Epoch 11/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2225 - accuracy: 0.9234
# Epoch 11: saving model to checkpoint\cp_0011.ckpt
# 309/309 [==============================] - 74s 239ms/step - loss: 0.2225 - accuracy: 0.9234 - val_loss: 0.4898 - val_accuracy: 0.8499 - lr: 5.0000e-06
# Epoch 12/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2111 - accuracy: 0.9274
# Epoch 12: saving model to checkpoint\cp_0012.ckpt
# 309/309 [==============================] - 73s 237ms/step - loss: 0.2111 - accuracy: 0.9274 - val_loss: 0.4901 - val_accuracy: 0.8484 - lr: 5.0000e-06
# Epoch 13/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2158 - accuracy: 0.9257
# Epoch 13: saving model to checkpoint\cp_0013.ckpt
# 309/309 [==============================] - 73s 238ms/step - loss: 0.2158 - accuracy: 0.9257 - val_loss: 0.4893 - val_accuracy: 0.8501 - lr: 5.0000e-06
# Epoch 14/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2106 - accuracy: 0.9273
# Epoch 14: saving model to checkpoint\cp_0014.ckpt
# 309/309 [==============================] - 73s 237ms/step - loss: 0.2106 - accuracy: 0.9273 - val_loss: 0.4882 - val_accuracy: 0.8490 - lr: 5.0000e-06
# Epoch 15/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2142 - accuracy: 0.9271
# Epoch 15: saving model to checkpoint\cp_0015.ckpt
# 309/309 [==============================] - 74s 238ms/step - loss: 0.2142 - accuracy: 0.9271 - val_loss: 0.4864 - val_accuracy: 0.8484 - lr: 5.0000e-06
# Epoch 16/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9330
# Epoch 16: saving model to checkpoint\cp_0016.ckpt
# 309/309 [==============================] - 73s 237ms/step - loss: 0.1974 - accuracy: 0.9330 - val_loss: 0.4887 - val_accuracy: 0.8496 - lr: 5.0000e-06
# Epoch 17/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2066 - accuracy: 0.9330
# Epoch 17: saving model to checkpoint\cp_0017.ckpt
# 309/309 [==============================] - 74s 239ms/step - loss: 0.2066 - accuracy: 0.9330 - val_loss: 0.4867 - val_accuracy: 0.8501 - lr: 5.0000e-06
# Epoch 18/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9356
# Epoch 18: saving model to checkpoint\cp_0018.ckpt
# 309/309 [==============================] - 73s 237ms/step - loss: 0.1945 - accuracy: 0.9356 - val_loss: 0.4847 - val_accuracy: 0.8510 - lr: 5.0000e-06
# Epoch 19/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1957 - accuracy: 0.9347
# Epoch 19: saving model to checkpoint\cp_0019.ckpt
# 309/309 [==============================] - 73s 238ms/step - loss: 0.1957 - accuracy: 0.9347 - val_loss: 0.4842 - val_accuracy: 0.8510 - lr: 5.0000e-06
# Epoch 20/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9341
# Epoch 20: saving model to checkpoint\cp_0020.ckpt
# 309/309 [==============================] - 74s 238ms/step - loss: 0.1913 - accuracy: 0.9341 - val_loss: 0.4850 - val_accuracy: 0.8522 - lr: 5.0000e-06
# Epoch 21/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2028 - accuracy: 0.9311
# Epoch 21: saving model to checkpoint\cp_0021.ckpt
# 309/309 [==============================] - 73s 238ms/step - loss: 0.2028 - accuracy: 0.9311 - val_loss: 0.4864 - val_accuracy: 0.8501 - lr: 4.7561e-06
# Epoch 22/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9342
# Epoch 22: saving model to checkpoint\cp_0022.ckpt
# 309/309 [==============================] - 74s 238ms/step - loss: 0.1921 - accuracy: 0.9342 - val_loss: 0.4848 - val_accuracy: 0.8519 - lr: 4.5242e-06
# Epoch 23/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1901 - accuracy: 0.9376
# Epoch 23: saving model to checkpoint\cp_0023.ckpt
# 309/309 [==============================] - 74s 239ms/step - loss: 0.1901 - accuracy: 0.9376 - val_loss: 0.4853 - val_accuracy: 0.8501 - lr: 4.3035e-06
# Epoch 24/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9330
# Epoch 24: saving model to checkpoint\cp_0024.ckpt
# 309/309 [==============================] - 74s 238ms/step - loss: 0.1971 - accuracy: 0.9330 - val_loss: 0.4836 - val_accuracy: 0.8501 - lr: 4.0937e-06
# Epoch 25/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1847 - accuracy: 0.9381
# Epoch 25: saving model to checkpoint\cp_0025.ckpt
# 309/309 [==============================] - 73s 238ms/step - loss: 0.1847 - accuracy: 0.9381 - val_loss: 0.4811 - val_accuracy: 0.8499 - lr: 3.8940e-06
# Epoch 26/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1834 - accuracy: 0.9380
# Epoch 26: saving model to checkpoint\cp_0026.ckpt
# 309/309 [==============================] - 74s 238ms/step - loss: 0.1834 - accuracy: 0.9380 - val_loss: 0.4852 - val_accuracy: 0.8507 - lr: 3.7041e-06
# Epoch 27/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9332
# Epoch 27: saving model to checkpoint\cp_0027.ckpt
# 309/309 [==============================] - 74s 238ms/step - loss: 0.1988 - accuracy: 0.9332 - val_loss: 0.4831 - val_accuracy: 0.8531 - lr: 3.5234e-06
# Epoch 28/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1813 - accuracy: 0.9402
# Epoch 28: saving model to checkpoint\cp_0028.ckpt
# 309/309 [==============================] - 74s 238ms/step - loss: 0.1813 - accuracy: 0.9402 - val_loss: 0.4834 - val_accuracy: 0.8525 - lr: 3.3516e-06
# Epoch 29/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1767 - accuracy: 0.9393
# Epoch 29: saving model to checkpoint\cp_0029.ckpt
# 309/309 [==============================] - 73s 238ms/step - loss: 0.1767 - accuracy: 0.9393 - val_loss: 0.4825 - val_accuracy: 0.8519 - lr: 3.1881e-06
# Epoch 30/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1870 - accuracy: 0.9381
# Epoch 30: saving model to checkpoint\cp_0030.ckpt
# 309/309 [==============================] - 74s 239ms/step - loss: 0.1870 - accuracy: 0.9381 - val_loss: 0.4818 - val_accuracy: 0.8516 - lr: 3.0327e-06

# %%
# TODO 11 (required) - plot training history
border2 = len(hist.history['loss'] + hist_fine.history['loss'])
ft2_tr_loss = hist.history['loss'] + hist_fine.history['loss'] + hist_fine_2.history['loss']
ft2_tr_acc = hist.history['accuracy'] + hist_fine.history['accuracy'] + hist_fine_2.history['accuracy']
ft2_val_loss = hist.history['val_loss'] + hist_fine.history['val_loss'] + hist_fine_2.history['val_loss']
ft2_val_acc = hist.history['val_accuracy'] + hist_fine.history['val_accuracy'] + hist_fine_2.history['val_accuracy']
epochs = range(1, len(ft2_tr_loss) + 1)

# Visualizing training and validation loss
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.axvline(x=border, color='red', linestyle='--', label='')
plt.axvline(x=border2, color='red', linestyle='--', label='')
plt.plot(epochs, ft2_tr_loss, label='Training Loss')
plt.plot(epochs, ft2_val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.axvline(x=border, color='red', linestyle='--', label='')
plt.axvline(x=border2, color='red', linestyle='--', label='')
plt.plot(epochs, ft2_tr_acc, label='Training Accuracy')
plt.plot(epochs, ft2_val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Fine-tuning stage III

# %%
model = tf.keras.models.load_model('fine_tune_2.keras')

# %%
base_model.trainable = True
# unfreeze the last 20 layers (was 14 layers)
for layer in base_model.layers[:-20]:
	layer.trainable = False

# %%
for layer in base_model.layers:
  print("{}: {}".format(layer, layer.trainable))

model.summary()
# Out:
# <keras.engine.input_layer.InputLayer object at 0x000001B7DB906430>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B7CD772250>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B7DB917790>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B7DB917670>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788ECF2E0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788EE0D00>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788EE0CD0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788EF7D90>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788EF7550>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F0D5E0>: False
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x000001B788EF7EE0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F10C70>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F17D00>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F1D700>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F172E0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F1D8B0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F296A0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F298B0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F2FFD0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F369D0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F36250>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F360A0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F4A160>: False
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x000001B788F3EFD0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F436A0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F4FFD0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F589D0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F4F5E0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F4F460>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F29790>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F254F0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F06670>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B7DC10ED00>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788ECFFA0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F62520>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F66310>: False
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x000001B788F66FD0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F68580>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F6B550>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788ECFFD0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F66850>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F68A00>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F71E20>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F7D490>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F817F0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F871F0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F87190>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F87C70>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788F955E0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788F90A00>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F9BF70>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FAB040>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788FAB550>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FAB340>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FB3100>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788FB3B80>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FBB7C0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FC2250>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788FC2F40>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FC2A60>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FB3FD0>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788FCA6D0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FD6EB0>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FE61F0>: False
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788FE61C0>: False
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FE6C40>: False
# <keras.layers.activation.relu.ReLU object at 0x000001B788FB3190>: False
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788FAB5B0>: True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FD6F10>: True
# <keras.layers.activation.relu.ReLU object at 0x000001B788F81220>: True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788F7D2E0>: True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788F7D100>: True
# <keras.layers.activation.relu.ReLU object at 0x000001B788F877C0>: True
# <keras.layers.reshaping.zero_padding2d.ZeroPadding2D object at 0x000001B788F4F070>: True
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B788FE9550>: True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FEB460>: True
# <keras.layers.activation.relu.ReLU object at 0x000001B788F663D0>: True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B788FEB070>: True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B788FE96D0>: True
# <keras.layers.activation.relu.ReLU object at 0x000001B78CFC1160>: True
# <keras.layers.convolutional.depthwise_conv2d.DepthwiseConv2D object at 0x000001B78CFC1BE0>: True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B78CFC3730>: True
# <keras.layers.activation.relu.ReLU object at 0x000001B78CFCA130>: True
# <keras.layers.convolutional.conv2d.Conv2D object at 0x000001B78CFCAFD0>: True
# <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x000001B78CFCAAF0>: True
# <keras.layers.activation.relu.ReLU object at 0x000001B78CFD54F0>: True
# <keras.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D object at 0x000001B78CFD08B0>: True
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 1024)             3228864
#  nal)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 11)                11275
#
# =================================================================
# Total params: 3,240,139
# Trainable params: 1,073,163
# Non-trainable params: 2,166,976
# _________________________________________________________________

# %%
first_ft_lr = hist_fine_2.history['lr'][0]
last_ft_lr = hist_fine_2.history['lr'][-1]
third_ft_lr = first_ft_lr*1/2
print("First fine tuning learning rate decay from", first_ft_lr, "to", last_ft_lr)
print("Second fine tuning learning rate:", third_ft_lr)
# model.compile(...)
opt = tf.keras.optimizers.Adam(learning_rate=third_ft_lr)
model.compile(
    optimizer=opt,
    loss=tf.keras.losses.sparse_categorical_crossentropy,
    metrics=['accuracy']
)
# Out:
# First fine tuning learning rate decay from 5.000000237487257e-06 to 3.0326534426064697e-06
# Second fine tuning learning rate: 2.5000001187436284e-06

# %%
ft3_early_stopping_callback = tf.keras.callbacks.EarlyStopping(monitor="val_accuracy",
                                                           min_delta=0.0005,
                                                           patience=5,
                                                           restore_best_weights=True)
def ft3_scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * np.exp(-0.05)
ft3_lr_scheduler = tf.keras.callbacks.LearningRateScheduler(ft3_scheduler, verbose=0)

# %%
n_epochs_fine3 = 200
hist_fine_3 = model.fit(x=training_gen, 
                    epochs=n_epochs_fine3,
                    validation_data=validation_gen, 
                    batch_size=BATCH_SIZE, 
                    callbacks=[cp_callback, 
                               ft3_early_stopping_callback,
                               ft3_lr_scheduler])
model.save('fine_tune_3.keras')
np.save('hist_fine_3.npy',hist_fine_3.history)
# Out:
# Epoch 1/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2001 - accuracy: 0.9308
# Epoch 1: saving model to checkpoint\cp_0001.ckpt
# 309/309 [==============================] - 78s 249ms/step - loss: 0.2001 - accuracy: 0.9308 - val_loss: 0.4840 - val_accuracy: 0.8516 - lr: 2.5000e-06
# Epoch 2/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1939 - accuracy: 0.9339
# Epoch 2: saving model to checkpoint\cp_0002.ckpt
# 309/309 [==============================] - 74s 239ms/step - loss: 0.1939 - accuracy: 0.9339 - val_loss: 0.4827 - val_accuracy: 0.8510 - lr: 2.5000e-06
# Epoch 3/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9353
# Epoch 3: saving model to checkpoint\cp_0003.ckpt
# 309/309 [==============================] - 74s 240ms/step - loss: 0.1936 - accuracy: 0.9353 - val_loss: 0.4831 - val_accuracy: 0.8522 - lr: 2.5000e-06
# Epoch 4/200
# 309/309 [==============================] - ETA: 0s - loss: 0.2020 - accuracy: 0.9294
# Epoch 4: saving model to checkpoint\cp_0004.ckpt
# 309/309 [==============================] - 77s 248ms/step - loss: 0.2020 - accuracy: 0.9294 - val_loss: 0.4836 - val_accuracy: 0.8525 - lr: 2.5000e-06
# Epoch 5/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9317
# Epoch 5: saving model to checkpoint\cp_0005.ckpt
# 309/309 [==============================] - 73s 238ms/step - loss: 0.1997 - accuracy: 0.9317 - val_loss: 0.4835 - val_accuracy: 0.8510 - lr: 2.5000e-06
# Epoch 6/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9352
# Epoch 6: saving model to checkpoint\cp_0006.ckpt
# 309/309 [==============================] - 73s 235ms/step - loss: 0.1892 - accuracy: 0.9352 - val_loss: 0.4825 - val_accuracy: 0.8516 - lr: 2.5000e-06
# Epoch 7/200
# 308/309 [============================>.] - ETA: 0s - loss: 0.1829 - accuracy: 0.9385
# Epoch 7: saving model to checkpoint\cp_0007.ckpt
# 309/309 [==============================] - 74s 240ms/step - loss: 0.1832 - accuracy: 0.9384 - val_loss: 0.4821 - val_accuracy: 0.8525 - lr: 2.5000e-06
# Epoch 8/200
# 309/309 [==============================] - ETA: 0s - loss: 0.1901 - accuracy: 0.9378
# Epoch 8: saving model to checkpoint\cp_0008.ckpt
# 309/309 [==============================] - 73s 237ms/step - loss: 0.1901 - accuracy: 0.9378 - val_loss: 0.4805 - val_accuracy: 0.8513 - lr: 2.5000e-06

# %%
# TODO 11 (required) - plot training history
border3 = len(hist.history['loss'] + hist_fine.history['loss']+ hist_fine_2.history['loss'])
ft3_tr_loss = hist.history['loss'] + hist_fine.history['loss'] + hist_fine_2.history['loss'] + hist_fine_3.history['loss']
ft3_tr_acc = hist.history['accuracy'] + hist_fine.history['accuracy'] + hist_fine_2.history['accuracy'] + hist_fine_3.history['accuracy']
ft3_val_loss = hist.history['val_loss'] + hist_fine.history['val_loss'] + hist_fine_2.history['val_loss'] + hist_fine_3.history['val_loss']
ft3_val_acc = hist.history['val_accuracy'] + hist_fine.history['val_accuracy'] + hist_fine_2.history['val_accuracy'] + hist_fine_3.history['val_accuracy']
epochs = range(1, len(ft3_tr_loss) + 1)

# Visualizing training and validation loss
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
plt.axvline(x=border, color='red', linestyle='--', label='')
plt.axvline(x=border2, color='red', linestyle='--', label='')
plt.axvline(x=border3, color='red', linestyle='--', label='')
plt.plot(epochs, ft3_tr_loss, label='Training Loss')
plt.plot(epochs, ft3_val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.axvline(x=border, color='red', linestyle='--', label='')
plt.axvline(x=border2, color='red', linestyle='--', label='')
plt.axvline(x=border3, color='red', linestyle='--', label='')
plt.plot(epochs, ft3_tr_acc, label='Training Accuracy')
plt.plot(epochs, ft3_val_acc, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Evaluate model performance

# %% [markdown]
# Once you have finished training your model, use `evaluate` to get the model performance - loss and accuracy - on the evaluation set. (You should not use the evaluation set at all prior to this step.)

# %%
K.clear_session()
model = tf.keras.models.load_model('vgg16_fine_tune.keras')
model.evaluate(evaluation_gen)
# Out:
# 105/105 [==============================] - 13s 126ms/step - loss: 0.9313 - accuracy: 0.6878
# [0.931343674659729, 0.6877800822257996]

# %% [markdown]
# We can also create a confusion matrix, to see which which classes are most often confused with one another.

# %%
y_pred_prob = model.predict(evaluation_gen)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 105/105 [==============================] - 9s 85ms/step

# %%
cm = pd.crosstab(evaluation_gen.classes, y_pred,
                               rownames=['Actual'], colnames=['Predicted'],
                               normalize='index')
p = plt.figure(figsize=(10,10));
p = sns.heatmap(cm, annot=True, fmt=".2f", cbar=False);
p = plt.xticks(ticks=np.arange(0,11), labels=classes, rotation=45)
p = plt.yticks(ticks=np.arange(0,11), labels=classes, rotation=45)

# %% [markdown]
# ## Save your model

# %% [markdown]
# Use the following cell to save your model:

# %%
model.save("model.keras")

# %% [markdown]
# Then, download it for later use.

# %%
from google.colab import files
files.download('model.keras')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 from google.colab import files
#       2 files.download('model.keras')
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# ## Use model on your own custom image

# %% [markdown]
# Take your own photograph of a food item in one of the 11 classes. Upload it to Colab, load it as a numpy array, and process the image (resize it, and scale so that each pixel takes on a value from 0 to 1).
#
# Then, use the fitted model to get the per-class probabilities for each class.
#
#
# Plot your image, and a bar plot showing the probability for the 5 most likely classes according to the model.
#
# (You can refer to the "Classify with MobileNetV2" section of this week's notebook for an example.)

# %%
# TODO 12 (required) - show example of model use on a new image
img = Image.open("custom_image_meat.jpg")
print(img.size)
width, height = img.size[0], img.size[1]
if height > width:
    width, height = height, width
left = width // 2 - height // 2
right = width // 2 + height // 2
upper = 0
lower = height

cropped_img = img.crop((left, upper, right, lower))
resize_img = cropped_img.resize([INPUT_IMG_SIZE, INPUT_IMG_SIZE])
img_arr = np.reshape(np.array(resize_img) / 255.0, (1, INPUT_IMG_SIZE, INPUT_IMG_SIZE, 3))
print(img_arr.shape)
K.clear_session()
model = tf.keras.models.load_model('./submission/fine_tune_2.keras')
y_pred_prob_custom = model.predict(img_arr)
y_pred_custom = np.argmax(y_pred_prob_custom, axis=1)
sorted_class_indexes = np.argsort(y_pred_prob_custom)[0]
sorted_class_prob = np.sort(y_pred_prob_custom, axis=1)[0]
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.imshow(resize_img)

plt.subplot(1,2,2)
bar_wid = 0.5
ind = np.arange(len(classes))
plt.yticks(rotation=30)
plt.barh(classes[list(sorted_class_indexes)][-5:], sorted_class_prob[-5:], bar_wid)

plt.ylabel("Classes")
plt.xlabel("Probabilities")
plt.legend()

plt.show()
# Out:
# (1920, 1080)
# (1, 224, 224, 3)
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001565D287670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 180ms/step
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
K.clear_session()
print("Fine tune I")
fine_tune_model = tf.keras.models.load_model('fine_tune.keras')
fine_tune_model.evaluate(evaluation_gen)
K.clear_session()
print("Fine tune II")
fine_tune_2_model = tf.keras.models.load_model('fine_tune_2.keras')
fine_tune_2_model.evaluate(evaluation_gen)
K.clear_session()
print("Fine tune III")
fine_tune_3_model = tf.keras.models.load_model('fine_tune_3.keras')
fine_tune_3_model.evaluate(evaluation_gen)
# Out:
# Fine tune I
# 105/105 [==============================] - 10s 87ms/step - loss: 0.4138 - accuracy: 0.8685
# Fine tune II
# 105/105 [==============================] - 9s 84ms/step - loss: 0.3995 - accuracy: 0.8742
# Fine tune III
# 105/105 [==============================] - 9s 83ms/step - loss: 0.3986 - accuracy: 0.8730
# [0.39859968423843384, 0.873020589351654]

# %% [markdown]
# ## Describe your model - TODO 13 (required)
#
# In the following cell, describe your final model and your results, by answering the following questions.
#
# * What base model did you use? How many parameters does this base model have?
# * Describe the specific transformations you used to create an augmented data set.
# * For how many epochs did you train your classification head, and with what optimizer, learning rate, and batch size? What was the validation accuracy at the end of this training stage?
# * Which layers did you un-freeze for fine-tuning, how many epochs did you fine-tune for, and what optimizer, learning rate, and batch size did you use for fine-tuning? What was the validation accuracy at the end of this training stage?
# * What was your final accuracy on the evaluation set?
# * Did your model correctly predict the class of your custom test image?

# %% [markdown]
# * I used the built-in MobileNet. The model has 3,228,864 paramemters.
# * The augmentations used are the default ones provided by Professor Fund. (Explanation for these augmentations quoted from docstring of ` tf.keras.preprocessing.image.ImageDataGenerator`)
#     * `rescale=1.0/255`: Rescale all pixels into [0, 1] range;
#     * `rotation_range=1`: degree range for random rotations;
# 	* `zoom_range=0.1`：range for random zoom;
# 	* `width_shift_range=0.1`：fraction of total width shifted horizontally;
# 	* `height_shift_range=0.1`：fraction of total height shifted vertically;
# 	* `shear_range=0.1`：the intensity of image being sheared;
# 	* `horizontal_flip=True`：image is filpped horizontally randomly;
# 	* `fill_mode="nearest"`: points outside the boundaries of the input are filled with nearest mode;
# * I trained the classification head 35 epochs, with Adam optimizer, learning rate of 0.001, amd batch size of 32. The validation accuracy at the end of this training stage is 0.8318.
# * There are three stages of un-freezing:
# 	1. Last 7 layers un-frozen:
# 		- epoch: 28, optimizer: Adam, learning rate: 1e-05, batch size: 32, validation accuracy: 0.8370;
# 	2. Last 14 layers un-frozen:
# 		- epoch: 30, optimizer: Adam, learning rate: 5e-06, batch size: 32, validation accuracy: 0.8516;
# 	3. Last 20 layers un-frozen:
# 		- epoch: 8, optimizer: Adam, learning rate: 2.5e-06, batch size: 32, validation accuracy: 0.8513;
# 	Since the third stage of un-freezing has no improvement in accucary, the final model is the second stage model (14 layers un-frozen)
# * The final accuracy is 0.8742
# * My model correctly predict the calss of my custom test image.
